# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create a sequence of odd numbers
sequence_length = 100
odd_numbers_sequence = np.arange(1, sequence_length * 2, step=2)

# Prepare the data for training
X_train = odd_numbers_sequence[:-1]  # Input sequence
y_train = odd_numbers_sequence[1:]   # Target (predict the next digit)

# Build a simple neural network model
model = Sequential()
model.add(Dense(10, input_dim=1, activation='relu'))  # Input layer with 10 neurons
model.add(Dense(1, activation='linear'))             # Output layer with 1 neuron

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=1)

# Generate predictions
predictions = model.predict(X_train)

# Print the predicted sequence
predicted_sequence = np.round(predictions.flatten()).astype(int)
print("Predicted Sequence:", predicted_sequence)
# Out:
# Epoch 1/50
# 99/99 [==============================] - 1s 2ms/step - loss: 15924.0508
# Epoch 2/50
# 99/99 [==============================] - 0s 2ms/step - loss: 9210.8027
# Epoch 3/50
# 99/99 [==============================] - 0s 2ms/step - loss: 4552.4482
# Epoch 4/50
# 99/99 [==============================] - 0s 2ms/step - loss: 1637.2214
# Epoch 5/50
# 99/99 [==============================] - 0s 3ms/step - loss: 389.6187
# Epoch 6/50
# 99/99 [==============================] - 0s 2ms/step - loss: 56.6176
# Epoch 7/50
# 99/99 [==============================] - 0s 2ms/step - loss: 5.7161
# Epoch 8/50
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5977
# Epoch 9/50
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2971
# Epoch 10/50
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2824
# Epoch 11/50
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2822
# Epoch 12/50
# ...
